# %%
# %matplotlib inline
datapath = "../data/dl1/objnc/rep/dogscats/nofinetune/"
fraction = 0.9
models = ['lambda_1','pool1','pool2','pool3',\
          'pool4','pool5','d1','d2','d3']

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress, spearmanr, pearsonr
import dimest; reload(dimest)
plt.style.use('ggplot')

# %%
D = np.load(datapath + 'D_sq_train.npy')

# %%
R = []
for i in range(len(D)):
    R.append(dimest.estimate_dim(D[i], fraction, False))

# %%
dimest.plot_correlations(R,models)

# %%
dimest.plot_cumulatives(R,fraction,models)

# %%
datapath = "../data/dl1/objnc/rep/dogscats/finetune/"

# %%
D = np.load(datapath + 'D_sq_train.npy')

# %%
R_ft = []
for i in range(len(D)):
    R_ft.append(dimest.estimate_dim(D[i], fraction, False))

# %%
R_ft
# Out:
# [(array([  5.85162633e-04,   1.04362710e-03,   1.12750618e-03, ...,
#            6.29441323e+00,   6.29625812e+00,   1.65086463e+01]),
#   array([ -0.00000000e+00,   5.00125042e-04,   1.00050033e-03, ...,
#            6.21460810e+00,   6.50229017e+00,   6.90775528e+00]),
#   LinregressResult(slope=0.95408636402638469, intercept=0.014511205908351421, rvalue=0.99960543649735778, pvalue=0.0, stderr=0.00063225874552445165),
#   0.99960543649735789,
#   0.0)]

# %%
dimest.plot_cumulatives(R_ft,fraction,models[-1])

# %%
dimest.plot_dimensions(R,models)
